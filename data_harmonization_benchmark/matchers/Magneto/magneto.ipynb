# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
# !pip install mmh3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mmh3
#   Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Downloading mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: mmh3
# Successfully installed mmh3-5.0.1
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import logging
from typing import Any, Dict, Optional

import pandas as pd
from valentine import valentine_match

from match_maker.match_maker import MatchMaker

logger = logging.getLogger(__name__)

def matching(
    usecase: str,
    usecase_path: str,
    source: pd.DataFrame,
    target: pd.DataFrame,
    top_k: int = 20,
    use_gpu: bool = False,
    config: Optional[Dict[str, Any]] = dict(
        use_bp_reranker=False,
        use_gpt_reranker=True
    ),
):
    


    matcher = MatchMaker(topk=top_k, **config)
    matches = valentine_match(source, target, matcher)

    return matches

# %%
import os

data_dir = "../../datasets/ChEMBL/Joinable/assays_vertical_50_ac2_ev/"
source = pd.read_csv(os.path.join(data_dir, "source.csv"))
target = pd.read_csv(os.path.join(data_dir, "target.csv"))


matching("ChEMBL", data_dir, source, target)
# Out:
# Loaded ZeroShot Model on cpu
# Applying GPT reranker
# {(('table_1', 'description'), ('table_2', 'Descr')): 1.0,
#  (('table_1', 'assay_id'), ('table_2', 'ASSI')): 1.0,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'ASSUBFR')): 1.0,
#  (('table_1', 'assay_test_type'), ('table_2', 'ASSTT')): 1.0,
#  (('table_1', 'assay_tax_id'), ('table_2', 'ASTAI')): 1.0,
#  (('table_1', 'curated_by'), ('table_2', 'CUB')): 1.0,
#  (('table_1', 'cell_id'), ('table_2', 'CEI')): 1.0,
#  (('table_1', 'relationship_type'), ('table_2', 'RELATIT')): 1.0,
#  (('table_1', 'tissue_id'), ('table_2', 'TISI')): 1.0,
#  (('table_1', 'src_id'), ('table_2', 'SRI')): 1.0,
#  (('table_1', 'doc_id'), ('table_2', 'ASSI')): 0.8,
#  (('table_1', 'assay_tissue'), ('table_2', 'ASSUBFR')): 0.3,
#  (('table_1', 'assay_category'), ('table_2', 'ASSCA')): 0.3,
#  (('table_1', 'assay_type'), ('table_2', 'ASSUBFR')): 0.3,
#  (('table_1', 'assay_category'), ('table_2', 'ASSTT')): 0.25,
#  (('table_1', 'assay_type'), ('table_2', 'RELATIT')): 0.25,
#  (('table_1', 'assay_category'), ('table_2', 'VARII')): 0.2,
#  (('table_1', 'assay_category'), ('table_2', 'SRASI')): 0.2,
#  (('table_1', 'assay_type'), ('table_2', 'ASSTT')): 0.2,
#  (('table_1', 'assay_category'), ('table_2', 'ASSUBFR')): 0.15,
#  (('table_1', 'assay_type'), ('table_2', 'CUB')): 0.15,
#  (('table_1', 'assay_test_type'), ('table_2', 'ASSUBFR')): 0.1,
#  (('table_1', 'assay_tax_id'), ('table_2', 'ASSI')): 0.1,
#  (('table_1', 'assay_tissue'), ('table_2', 'ASSTT')): 0.1,
#  (('table_1', 'assay_organism'), ('table_2', 'ASSUBFR')): 0.1,
#  (('table_1', 'assay_strain'), ('table_2', 'ASSUBFR')): 0.1,
#  (('table_1', 'assay_category'), ('table_2', 'CHI')): 0.1,
#  (('table_1', 'assay_category'), ('table_2', 'Ti')): 0.1,
#  (('table_1', 'assay_category'), ('table_2', 'BFOR')): 0.1,
#  (('table_1', 'assay_type'), ('table_2', 'SRI')): 0.1,
#  (('table_1', 'description'), ('table_2', 'ASSUBFR')): 0.05,
#  (('table_1', 'description'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'description'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'description'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'description'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'description'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'description'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'ASSUBFR')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'SRI')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'ASSCA')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'VARII')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'Descr')): 0.05,
#  (('table_1', 'assay_id'), ('table_2', 'SRASI')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'SRI')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'VARII')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'ASSUBFR')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'SRASI')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'ASSCA')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'doc_id'), ('table_2', 'Descr')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'Descr')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'SRI')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'assay_test_type'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'SRI')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'assay_tax_id'), ('table_2', 'ASSUBFR')): 0.05,
#  (('table_1', 'assay_tissue'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'assay_tissue'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'assay_tissue'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'ASSUBFR')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'curated_by'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'SRI')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'ASSUBFR')): 0.05,
#  (('table_1', 'cell_id'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'assay_organism'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'ASSUBFR')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'relationship_type'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'tissue_id'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'assay_strain'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'assay_category'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'assay_category'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'assay_category'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'assay_category'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'assay_category'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'assay_category'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'assay_category'), ('table_2', 'SRI')): 0.05,
#  (('table_1', 'assay_category'), ('table_2', 'Descr')): 0.05,
#  (('table_1', 'assay_type'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'assay_type'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'assay_type'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'assay_type'), ('table_2', 'Descr')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'Ti')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'ASTAI')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'ASSI')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'TISI')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'CEI')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'CHI')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'BFOR')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'CONSCO')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'CUB')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'VARII')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'ASSTT')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'ASSUBFR')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'SRASI')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'ASSCA')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'RELATIT')): 0.05,
#  (('table_1', 'src_id'), ('table_2', 'Descr')): 0.05,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'assay_subcellular_fraction'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'assay_test_type'), ('table_2', 'SRI')): 0.0,
#  (('table_1', 'assay_test_type'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'assay_test_type'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'assay_test_type'), ('table_2', 'Descr')): 0.0,
#  (('table_1', 'assay_tax_id'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'assay_tax_id'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'assay_tax_id'), ('table_2', 'RELATIT')): 0.0,
#  (('table_1', 'assay_tax_id'), ('table_2', 'CUB')): 0.0,
#  (('table_1', 'assay_tax_id'), ('table_2', 'Descr')): 0.0,
#  (('table_1', 'assay_tax_id'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'Ti')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'CONSCO')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'BFOR')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'Descr')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'SRI')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'TISI')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'CHI')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'CEI')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'ASTAI')): 0.0,
#  (('table_1', 'assay_tissue'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'curated_by'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'curated_by'), ('table_2', 'SRI')): 0.0,
#  (('table_1', 'curated_by'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'cell_id'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'cell_id'), ('table_2', 'Descr')): 0.0,
#  (('table_1', 'cell_id'), ('table_2', 'RELATIT')): 0.0,
#  (('table_1', 'cell_id'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'cell_id'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'assay_organism'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'assay_organism'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'assay_organism'), ('table_2', 'SRI')): 0.0,
#  (('table_1', 'assay_organism'), ('table_2', 'Descr')): 0.0,
#  (('table_1', 'assay_organism'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'relationship_type'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'relationship_type'), ('table_2', 'SRI')): 0.0,
#  (('table_1', 'relationship_type'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'relationship_type'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'Ti')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'CEI')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'ASSI')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'CHI')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'BFOR')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'CONSO')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'SRI')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'ASSUBFR')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'ASSTT')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'CUB')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'RELATIT')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'Descr')): 0.0,
#  (('table_1', 'tissue_id'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'assay_strain'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'assay_strain'), ('table_2', 'SRI')): 0.0,
#  (('table_1', 'assay_strain'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'assay_strain'), ('table_2', 'Descr')): 0.0,
#  (('table_1', 'assay_strain'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'ASSI')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'ASSUBFR')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'ASSTT')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'Ti')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'ASTAI')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'CHI')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'TISI')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'CEI')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'BFOR')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'SRI')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'CONSCO')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'Descr')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'CUB')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'ASSCA')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'RELATIT')): 0.0,
#  (('table_1', 'assay_cell_type'), ('table_2', 'SRASI')): 0.0,
#  (('table_1', 'assay_type'), ('table_2', 'VARII')): 0.0,
#  (('table_1', 'assay_type'), ('table_2', 'ASSI')): 0.0,
#  (('table_1', 'assay_type'), ('table_2', 'TISI')): 0.0,
#  (('table_1', 'assay_type'), ('table_2', 'BFOR')): 0.0,
#  (('table_1', 'assay_type'), ('table_2', 'CHI')): 0.0,
#  (('table_1', 'assay_type'), ('table_2', 'ASSCA')): 0.0}
